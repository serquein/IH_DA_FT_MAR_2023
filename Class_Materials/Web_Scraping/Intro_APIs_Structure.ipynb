# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(results)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '27105195558',
#   'type': 'IssuesEvent',
#   'actor': {'id': 58094558,
#    'login': 'pddemo',
#    'display_login': 'pddemo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pddemo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58094558?'},
#   'repo': {'id': 277422872,
#    'name': 'pddemo/demo',
#    'url': 'https://api.github.com/repos/pddemo/demo'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/pddemo/demo/issues/1344420',
#     'repository_url': 'https://api.github.com/repos/pddemo/demo',
#     'labels_url': 'https://api.github.com/repos/pddemo/demo/issues/1344420/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/pddemo/demo/issues/1344420/comments',
#     'events_url': 'https://api.github.com/repos/pddemo/demo/issues/1344420/events',
#     'html_url': 'https://github.com/pddemo/demo/issues/1344420',
#     'id': 1585700045,
#     'node_id': 'I_kwDOEIkjGM5eg9zN',
#     'number': 1344420,
#     'title': 'Practical Steel Pants',
#     'user': {'login': 'pddemo',
#      'id': 58094558,
#      'node_id': 'MDQ6VXNlcjU4MDk0NTU4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/58094558?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pddemo',
#      'html_url': 'https://github.com/pddemo',
#      'followers_url': 'https://api.github.com/users/pddemo/followers',
#      'following_url': 'https://api.github.com/users/pddemo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pddemo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pddemo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pddemo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pddemo/orgs',
#      'repos_url': 'https://api.github.com/users/pddemo/repos',
#      'events_url': 'https://api.github.com/users/pddemo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pddemo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2023-02-15T11:34:25Z',
#     'updated_at': '2023-02-15T11:34:25Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': None,
#     'reactions': {'url': 'https://api.github.com/repos/pddemo/demo/issues/1344420/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/pddemo/demo/issues/1344420/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195581',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 19198355,
#    'login': 'artiely',
#    'display_login': 'artiely',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/artiely',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19198355?'},
#   'repo': {'id': 287952716,
#    'name': 'chexiongsheng/puerts_unity_demo',
#    'url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo/issues/59',
#     'repository_url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo',
#     'labels_url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo/issues/59/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo/issues/59/comments',
#     'events_url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo/issues/59/events',
#     'html_url': 'https://github.com/chexiongsheng/puerts_unity_demo/issues/59',
#     'id': 1583383185,
#     'node_id': 'I_kwDOESnPTM5eYIKR',
#     'number': 59,
#     'title': 'Mac下打包 09_nodejs demo 的时候报错DllNotFoundException',
#     'user': {'login': 'artiely',
#      'id': 19198355,
#      'node_id': 'MDQ6VXNlcjE5MTk4MzU1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/19198355?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/artiely',
#      'html_url': 'https://github.com/artiely',
#      'followers_url': 'https://api.github.com/users/artiely/followers',
#      'following_url': 'https://api.github.com/users/artiely/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/artiely/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/artiely/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/artiely/subscriptions',
#      'organizations_url': 'https://api.github.com/users/artiely/orgs',
#      'repos_url': 'https://api.github.com/users/artiely/repos',
#      'events_url': 'https://api.github.com/users/artiely/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/artiely/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 7,
#     'created_at': '2023-02-14T02:28:36Z',
#     'updated_at': '2023-02-15T11:34:25Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '日志如下\r\n```\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.dylib\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.so\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.bundle\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/puerts\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.dylib\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.so\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.bundle\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.dylib\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.so\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.bundle\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/puerts\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.dylib\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.so\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.bundle\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.dylib\r\nFallback handler could not load library /Users/tanjie/Desktop/puerts_unity_demo-master/projects/0_Basic_Demo/1.app/Contents/Frameworks/MonoEmbedRuntime/osx/libpuerts.so\r\nFallback handler c ...
#     'reactions': {'url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo/issues/59/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo/issues/59/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo/issues/comments/1431227693',
#     'html_url': 'https://github.com/chexiongsheng/puerts_unity_demo/issues/59#issuecomment-1431227693',
#     'issue_url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo/issues/59',
#     'id': 1431227693,
#     'node_id': 'IC_kwDOESnPTM5VTs0t',
#     'user': {'login': 'artiely',
#      'id': 19198355,
#      'node_id': 'MDQ6VXNlcjE5MTk4MzU1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/19198355?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/artiely',
#      'html_url': 'https://github.com/artiely',
#      'followers_url': 'https://api.github.com/users/artiely/followers',
#      'following_url': 'https://api.github.com/users/artiely/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/artiely/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/artiely/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/artiely/subscriptions',
#      'organizations_url': 'https://api.github.com/users/artiely/orgs',
#      'repos_url': 'https://api.github.com/users/artiely/repos',
#      'events_url': 'https://api.github.com/users/artiely/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/artiely/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-02-15T11:34:25Z',
#     'updated_at': '2023-02-15T11:34:25Z',
#     'author_association': 'NONE',
#     'body': '> > > 现在仓库上是带有M1版本的binary的  @zombieyang\r\n> > \r\n> > \r\n> > 多谢回复,我使用的 unity2020,2021 我也试过一样的问题, mac 是 intel. 我删除了 arm64 下的所有.dylib 问题依旧.请问不是 M1 的该如何处理\r\n> \r\n> 那再确认下 x86_64下的`dylib`和`bundle`的平台设置是否正确？\r\n\r\n@zombieyang  平台设置? 需要怎么设置,除了 `sudo xattr -r -d com.apple.quarantine puerts.bundle` 之外还要做什么?',
#     'reactions': {'url': 'https://api.github.com/repos/chexiongsheng/puerts_unity_demo/issues/comments/1431227693/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195609',
#   'type': 'DeleteEvent',
#   'actor': {'id': 77505379,
#    'login': 'robert-craig-houston',
#    'display_login': 'robert-craig-houston',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/robert-craig-houston',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77505379?'},
#   'repo': {'id': 553213531,
#    'name': 'Esri/date',
#    'url': 'https://api.github.com/repos/Esri/date'},
#   'payload': {'ref': 'rob10470/expr1058_update_date_to_lowercase',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z',
#   'org': {'id': 628795,
#    'login': 'Esri',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Esri',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/628795?'}},
#  {'id': '27105195458',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 367179710,
#    'name': 'kisaragi-hiu/aqi-mirror',
#    'url': 'https://api.github.com/repos/kisaragi-hiu/aqi-mirror'},
#   'payload': {'repository_id': 367179710,
#    'push_id': 12628761364,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a6c29a133bf09c51f191b6cd5a1e36a61fcae331',
#    'before': 'a82230678d26e49e906b79d6a30e0c74f85e3ee3',
#    'commits': [{'sha': 'a6c29a133bf09c51f191b6cd5a1e36a61fcae331',
#      'author': {'email': 'kisaragi-hiu@users.noreply.github.com',
#       'name': 'kisaragi-hiu'},
#      'message': 'Commit from GitHub Actions (Mirror government AQI data)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kisaragi-hiu/aqi-mirror/commits/a6c29a133bf09c51f191b6cd5a1e36a61fcae331'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195547',
#   'type': 'PushEvent',
#   'actor': {'id': 69813706,
#    'login': 'SalmanNaghori',
#    'display_login': 'SalmanNaghori',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SalmanNaghori',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69813706?'},
#   'repo': {'id': 600827780,
#    'name': 'SalmanNaghori/shop_app',
#    'url': 'https://api.github.com/repos/SalmanNaghori/shop_app'},
#   'payload': {'repository_id': 600827780,
#    'push_id': 12628761409,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7f12a56e2eb16b669e1e08d6122dbf9969a13a88',
#    'before': '96f3e9754ebfbb1b90a860c0007d6859d53df2b0',
#    'commits': [{'sha': '65567f17f00588f5975183563ec3575c549f4833',
#      'author': {'email': 'salmannaghori@gmail.com', 'name': 'SalmanNaghori'},
#      'message': 'add product',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/SalmanNaghori/shop_app/commits/65567f17f00588f5975183563ec3575c549f4833'},
#     {'sha': '7f12a56e2eb16b669e1e08d6122dbf9969a13a88',
#      'author': {'email': '69813706+SalmanNaghori@users.noreply.github.com',
#       'name': 'SalmanNaghori'},
#      'message': 'Merge pull request #3 from SalmanNaghori/add_product\n\nadd product',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SalmanNaghori/shop_app/commits/7f12a56e2eb16b669e1e08d6122dbf9969a13a88'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195474',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 86929735,
#    'name': 'Lombiq/Orchard',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard'},
#   'payload': {'repository_id': 86929735,
#    'push_id': 12628761398,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/snippets',
#    'head': '1e2d919b02685bed0f0492aac2d59836a1413280',
#    'before': '1e2d919b02685bed0f0492aac2d59836a1413280',
#    'commits': []},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '27105195506',
#   'type': 'PushEvent',
#   'actor': {'id': 56868292,
#    'login': 'Zhytou',
#    'display_login': 'Zhytou',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Zhytou',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56868292?'},
#   'repo': {'id': 486866465,
#    'name': 'Zhytou/Zhytou',
#    'url': 'https://api.github.com/repos/Zhytou/Zhytou'},
#   'payload': {'repository_id': 486866465,
#    'push_id': 12628761383,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '51b0366f951138a7ac70aff1af748fd88a8b4cc5',
#    'before': 'b017e500ee149629e9a903cc7ee6c17d5532420d',
#    'commits': [{'sha': '51b0366f951138a7ac70aff1af748fd88a8b4cc5',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'readme-bot'},
#      'message': 'Updated with Dev Metrics',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Zhytou/Zhytou/commits/51b0366f951138a7ac70aff1af748fd88a8b4cc5'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195504',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 122006844,
#    'login': 'rioyulinanda',
#    'display_login': 'rioyulinanda',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rioyulinanda',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/122006844?'},
#   'repo': {'id': 601073114,
#    'name': 'revou-fsse-1/w5-company-website-group-a',
#    'url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a'},
#   'payload': {'action': 'opened',
#    'number': 5,
#    'pull_request': {'url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/pulls/5',
#     'id': 1241946015,
#     'node_id': 'PR_kwDOI9Ol2s5KBpef',
#     'html_url': 'https://github.com/revou-fsse-1/w5-company-website-group-a/pull/5',
#     'diff_url': 'https://github.com/revou-fsse-1/w5-company-website-group-a/pull/5.diff',
#     'patch_url': 'https://github.com/revou-fsse-1/w5-company-website-group-a/pull/5.patch',
#     'issue_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/issues/5',
#     'number': 5,
#     'state': 'open',
#     'locked': False,
#     'title': 'add section shop, changing readme content, and changing aboutus',
#     'user': {'login': 'rioyulinanda',
#      'id': 122006844,
#      'node_id': 'U_kgDOB0WtPA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/122006844?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rioyulinanda',
#      'html_url': 'https://github.com/rioyulinanda',
#      'followers_url': 'https://api.github.com/users/rioyulinanda/followers',
#      'following_url': 'https://api.github.com/users/rioyulinanda/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rioyulinanda/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rioyulinanda/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rioyulinanda/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rioyulinanda/orgs',
#      'repos_url': 'https://api.github.com/users/rioyulinanda/repos',
#      'events_url': 'https://api.github.com/users/rioyulinanda/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rioyulinanda/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'just add a section shop. including updating the readme and about us text',
#     'created_at': '2023-02-15T11:34:24Z',
#     'updated_at': '2023-02-15T11:34:24Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/pulls/5/commits',
#     'review_comments_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/pulls/5/comments',
#     'review_comment_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/issues/5/comments',
#     'statuses_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/statuses/53a5de11da59c2e3a5875f2974f1317e789b3498',
#     'head': {'label': 'revou-fsse-1:adding-sectionshop',
#      'ref': 'adding-sectionshop',
#      'sha': '53a5de11da59c2e3a5875f2974f1317e789b3498',
#      'user': {'login': 'revou-fsse-1',
#       'id': 119390055,
#       'node_id': 'O_kgDOBx2_Zw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/119390055?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/revou-fsse-1',
#       'html_url': 'https://github.com/revou-fsse-1',
#       'followers_url': 'https://api.github.com/users/revou-fsse-1/followers',
#       'following_url': 'https://api.github.com/users/revou-fsse-1/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/revou-fsse-1/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/revou-fsse-1/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/revou-fsse-1/subscriptions',
#       'organizations_url': 'https://api.github.com/users/revou-fsse-1/orgs',
#       'repos_url': 'https://api.github.com/users/revou-fsse-1/repos',
#       'events_url': 'https://api.github.com/users/revou-fsse-1/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/revou-fsse-1/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 601073114,
#       'node_id': 'R_kgDOI9Ol2g',
#       'name': 'w5-company-website-group-a',
#       'full_name': 'revou-fsse-1/w5-company-website-group-a',
#       'private': False,
#       'owner': {'login': 'revou-fsse-1',
#        'id': 119390055,
#        'node_id': 'O_kgDOBx2_Zw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/119390055?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/revou-fsse-1',
#        'html_url': 'https://github.com/revou-fsse-1',
#        'followers_url': 'https://api.github.com/users/revou-fsse-1/followers',
#        'following_url': 'https://api.github.com/users/revou-fsse-1/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/revou-fsse-1/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/revou-fsse-1/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/revou-fsse-1/subscriptions',
#        'organizations_url': 'https://api.github.com/users/revou-fsse-1/orgs',
#        'repos_url': 'https://api.github.com/users/revou-fsse-1/repos',
#        'events_url': 'https://api.github.com/users/revou-fsse-1/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/revou-fsse-1/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/revou-fsse-1/w5-company-website-group-a',
#       'description': 'w5-company-website-group-a created by GitHub Classroom',
#       'fork': False,
#       'url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a',
#       'forks_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/forks',
#       'keys_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/teams',
#       'hooks_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/hooks',
#       'issue_events_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/events',
#       'assignees_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/tags',
#       'blobs_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/languages',
#       'stargazers_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/stargazers',
#       'contributors_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/contributors',
#       'subscribers_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/subscribers',
#       'subscription_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/subscription',
#       'commits_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/merges',
#       'archive_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/downloads',
#       'issues_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/deployments',
#       'created_at': '2023-02-13T10:05:13Z',
#       'updated_at': '2023-02-14T14:19:15Z',
#       'pushed_at': '2023-02-15T11:33:30Z',
#       'git_url': 'git://github.com/revou-fsse-1/w5-company-website-group-a.git',
#       'ssh_url': 'git@github.com:revou-fsse-1/w5-company-website-group-a.git',
#       'clone_url': 'https://github.com/revou-fsse-1/w5-company-website-group-a.git',
#       'svn_url': 'https://github.com/revou-fsse-1/w5-company-website-group-a',
#       'homepage': None,
#       'size': 26614,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'CSS',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'revou-fsse-1:main',
#      'ref': 'main',
#      'sha': 'e0f583e2042c11b30cf904f0460bffd8e08e48d1',
#      'user': {'login': 'revou-fsse-1',
#       'id': 119390055,
#       'node_id': 'O_kgDOBx2_Zw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/119390055?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/revou-fsse-1',
#       'html_url': 'https://github.com/revou-fsse-1',
#       'followers_url': 'https://api.github.com/users/revou-fsse-1/followers',
#       'following_url': 'https://api.github.com/users/revou-fsse-1/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/revou-fsse-1/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/revou-fsse-1/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/revou-fsse-1/subscriptions',
#       'organizations_url': 'https://api.github.com/users/revou-fsse-1/orgs',
#       'repos_url': 'https://api.github.com/users/revou-fsse-1/repos',
#       'events_url': 'https://api.github.com/users/revou-fsse-1/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/revou-fsse-1/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 601073114,
#       'node_id': 'R_kgDOI9Ol2g',
#       'name': 'w5-company-website-group-a',
#       'full_name': 'revou-fsse-1/w5-company-website-group-a',
#       'private': False,
#       'owner': {'login': 'revou-fsse-1',
#        'id': 119390055,
#        'node_id': 'O_kgDOBx2_Zw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/119390055?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/revou-fsse-1',
#        'html_url': 'https://github.com/revou-fsse-1',
#        'followers_url': 'https://api.github.com/users/revou-fsse-1/followers',
#        'following_url': 'https://api.github.com/users/revou-fsse-1/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/revou-fsse-1/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/revou-fsse-1/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/revou-fsse-1/subscriptions',
#        'organizations_url': 'https://api.github.com/users/revou-fsse-1/orgs',
#        'repos_url': 'https://api.github.com/users/revou-fsse-1/repos',
#        'events_url': 'https://api.github.com/users/revou-fsse-1/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/revou-fsse-1/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/revou-fsse-1/w5-company-website-group-a',
#       'description': 'w5-company-website-group-a created by GitHub Classroom',
#       'fork': False,
#       'url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a',
#       'forks_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/forks',
#       'keys_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/teams',
#       'hooks_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/hooks',
#       'issue_events_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/events',
#       'assignees_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/tags',
#       'blobs_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/languages',
#       'stargazers_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/stargazers',
#       'contributors_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/contributors',
#       'subscribers_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/subscribers',
#       'subscription_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/subscription',
#       'commits_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/merges',
#       'archive_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/downloads',
#       'issues_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/deployments',
#       'created_at': '2023-02-13T10:05:13Z',
#       'updated_at': '2023-02-14T14:19:15Z',
#       'pushed_at': '2023-02-15T11:33:30Z',
#       'git_url': 'git://github.com/revou-fsse-1/w5-company-website-group-a.git',
#       'ssh_url': 'git@github.com:revou-fsse-1/w5-company-website-group-a.git',
#       'clone_url': 'https://github.com/revou-fsse-1/w5-company-website-group-a.git',
#       'svn_url': 'https://github.com/revou-fsse-1/w5-company-website-group-a',
#       'homepage': None,
#       'size': 26614,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'CSS',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/pulls/5'},
#      'html': {'href': 'https://github.com/revou-fsse-1/w5-company-website-group-a/pull/5'},
#      'issue': {'href': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/issues/5'},
#      'comments': {'href': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/issues/5/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/pulls/5/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/pulls/5/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/revou-fsse-1/w5-company-website-group-a/statuses/53a5de11da59c2e3a5875f2974f1317e789b3498'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 123,
#     'deletions': 11,
#     'changed_files': 7}},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z',
#   'org': {'id': 119390055,
#    'login': 'revou-fsse-1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/revou-fsse-1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119390055?'}},
#  {'id': '27105195500',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 601934771,
#    'name': 'stream-protocol/streampay-storefront',
#    'url': 'https://api.github.com/repos/stream-protocol/streampay-storefront'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/issues/1',
#     'repository_url': 'https://api.github.com/repos/stream-protocol/streampay-storefront',
#     'labels_url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/issues/1/events',
#     'html_url': 'https://github.com/stream-protocol/streampay-storefront/pull/1',
#     'id': 1585672881,
#     'node_id': 'PR_kwDOI-DLs85KBjpE',
#     'number': 1,
#     'title': 'Bump http-cache-semantics from 4.1.0 to 4.1.1',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 5157585241,
#       'node_id': 'LA_kwDOI-DLs88AAAABM2qBWQ',
#       'url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2023-02-15T11:14:43Z',
#     'updated_at': '2023-02-15T11:34:25Z',
#     'closed_at': '2023-02-15T11:34:22Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/pulls/1',
#      'html_url': 'https://github.com/stream-protocol/streampay-storefront/pull/1',
#      'diff_url': 'https://github.com/stream-protocol/streampay-storefront/pull/1.diff',
#      'patch_url': 'https://github.com/stream-protocol/streampay-storefront/pull/1.patch',
#      'merged_at': None},
#     'body': 'Bumps [http-cache-semantics](https://github.com/kornelski/http-cache-semantics) from 4.1.0 to 4.1.1.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/kornelski/http-cache-semantics/commit/24496504352199caf360d1b4d4a01efdc8a7249e"><code>2449650</code></a> Update mocha</li>\n<li><a href="https://github.com/kornelski/http-cache-semantics/commit/560b2d8ef452bbba20ffed69dc155d63ac757b74"><code>560b2d8</code></a> Don\'t use regex to trim whitespace</li>\n<li><a href="https://github.com/kornelski/http-cache-semantics/commit/b1bdb92638426fab978f31e1330b6833015cabf0"><code>b1bdb92</code></a> Remove linting package zoo</li>\n<li><a href="https://github.com/kornelski/http-cache-semantics/commit/c20dc7eeca608339143857953ee7ed9343fe6d3d"><code>c20dc7e</code></a> Cache 308</li>\n<li>See full diff in <a href="https://github.com/kornelski/http-cache-semantics/compare/v4.1.0...v4.1.1">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=http-cache-semantics&package-manager=npm_and_yarn&previous-version=4.1.0&new-version=4.1.1)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/stream-protocol/streampay-storefront/network/alerts).\n\n</details>',
#     'reactions': {'url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/issues/1/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/issues/1/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/issues/comments/1431227691',
#     'html_url': 'https://github.com/stream-protocol/streampay-storefront/pull/1#issuecomment-1431227691',
#     'issue_url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/issues/1',
#     'id': 1431227691,
#     'node_id': 'IC_kwDOI-DLs85VTs0r',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2023-02-15T11:34:25Z',
#     'updated_at': '2023-02-15T11:34:25Z',
#     'author_association': 'NONE',
#     'body': "OK, I won't notify you again about this release, but will get in touch when a new version is available. If you'd rather skip all updates until the next major or minor version, let me know by commenting `@dependabot ignore this major version` or `@dependabot ignore this minor version`.\n\nIf you change your mind, just re-open this PR and I'll resolve any conflicts on it.",
#     'reactions': {'url': 'https://api.github.com/repos/stream-protocol/streampay-storefront/issues/comments/1431227691/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195505',
#   'type': 'PushEvent',
#   'actor': {'id': 95034083,
#    'login': 'kAmAZ07',
#    'display_login': 'kAmAZ07',
#    'gravatar_id': '',
# ...
#       'tags_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/tags',
#       'blobs_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/languages',
#       'stargazers_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/subscription',
#       'commits_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/merges',
#       'archive_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/downloads',
#       'issues_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/deployments',
#       'created_at': '2019-12-02T13:51:37Z',
#       'updated_at': '2023-02-15T08:20:48Z',
#       'pushed_at': '2023-02-15T01:59:39Z',
#       'git_url': 'git://github.com/Fraunhofer-AISEC/cpg.git',
#       'ssh_url': 'git@github.com:Fraunhofer-AISEC/cpg.git',
#       'clone_url': 'https://github.com/Fraunhofer-AISEC/cpg.git',
#       'svn_url': 'https://github.com/Fraunhofer-AISEC/cpg',
#       'homepage': 'https://fraunhofer-aisec.github.io/cpg/',
#       'size': 65434,
#       'stargazers_count': 138,
#       'watchers_count': 138,
#       'language': 'Kotlin',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'has_discussions': True,
#       'forks_count': 46,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 80,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['analysis',
#        'c',
#        'code',
#        'code-property-graph',
#        'cpg',
#        'cpp',
#        'golang',
#        'graph',
#        'java',
#        'llvm-ir',
#        'python'],
#       'visibility': 'public',
#       'forks': 46,
#       'open_issues': 80,
#       'watchers': 138,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/pulls/1087'},
#      'html': {'href': 'https://github.com/Fraunhofer-AISEC/cpg/pull/1087'},
#      'issue': {'href': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/issues/1087'},
#      'comments': {'href': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/issues/1087/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/pulls/1087/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/pulls/1087/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Fraunhofer-AISEC/cpg/statuses/5cf613331f2648ae87352b7bacc7410fe5421ed2'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-02-15T11:34:24Z',
#   'org': {'id': 11649721,
#    'login': 'Fraunhofer-AISEC',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Fraunhofer-AISEC',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11649721?'}},
#  {'id': '27105195412',
#   'type': 'PushEvent',
#   'actor': {'id': 1318985,
#    'login': 'marianzburlea',
#    'display_login': 'marianzburlea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marianzburlea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1318985?'},
#   'repo': {'id': 602040023,
#    'name': 'wowdop/blog-next-12-13',
#    'url': 'https://api.github.com/repos/wowdop/blog-next-12-13'},
#   'payload': {'repository_id': 602040023,
#    'push_id': 12628761340,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7fccc3c44e5f7512aa9ca26ec25079c3d2904620',
#    'before': '98c734a0346cf231bdcc4aee7e235dc6e87600cf',
#    'commits': [{'sha': '7fccc3c44e5f7512aa9ca26ec25079c3d2904620',
#      'author': {'email': 'marian@wowdop.com', 'name': 'Marian Zburlea'},
#      'message': 'feat: add link to github and from github',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wowdop/blog-next-12-13/commits/7fccc3c44e5f7512aa9ca26ec25079c3d2904620'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z',
#   'org': {'id': 86354869,
#    'login': 'wowdop',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wowdop',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86354869?'}},
#  {'id': '27105195418',
#   'type': 'PublicEvent',
#   'actor': {'id': 114900529,
#    'login': 'iliaquatali',
#    'display_login': 'iliaquatali',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iliaquatali',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/114900529?'},
#   'repo': {'id': 590427692,
#    'name': 'iliaquatali/Laravel-9-Rest-API-Crud',
#    'url': 'https://api.github.com/repos/iliaquatali/Laravel-9-Rest-API-Crud'},
#   'payload': {},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195410',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 63333828,
#    'name': 'JasperFx/oakton',
#    'url': 'https://api.github.com/repos/JasperFx/oakton'},
#   'payload': {'repository_id': 63333828,
#    'push_id': 12628761349,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'b06a687fe59d6ec8f0fd7bfee8d2398e1e45e7d0',
#    'before': '4d33f716a0a78e59a62758f020cc4de7f1b1bab7',
#    'commits': [{'sha': 'b06a687fe59d6ec8f0fd7bfee8d2398e1e45e7d0',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'Documentation Update for 6.0.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JasperFx/oakton/commits/b06a687fe59d6ec8f0fd7bfee8d2398e1e45e7d0'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z',
#   'org': {'id': 10048186,
#    'login': 'JasperFx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/JasperFx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10048186?'}},
#  {'id': '27105195406',
#   'type': 'PushEvent',
#   'actor': {'id': 79570884,
#    'login': 'RickHalmoguera',
#    'display_login': 'RickHalmoguera',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RickHalmoguera',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79570884?'},
#   'repo': {'id': 601752040,
#    'name': 'RickHalmoguera/Planets-fact-site',
#    'url': 'https://api.github.com/repos/RickHalmoguera/Planets-fact-site'},
#   'payload': {'repository_id': 601752040,
#    'push_id': 12628761379,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '77255ee92178d0b212a8280f1384e9c1261f607d',
#    'before': '25ab0cbab3b8743d349008bd54402280a0166b5c',
#    'commits': [{'sha': '77255ee92178d0b212a8280f1384e9c1261f607d',
#      'author': {'email': 'halmoguerar@gmail.com', 'name': 'Ricardo'},
#      'message': 'change css',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RickHalmoguera/Planets-fact-site/commits/77255ee92178d0b212a8280f1384e9c1261f607d'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195449',
#   'type': 'PushEvent',
#   'actor': {'id': 80437879,
#    'login': 'etawia',
#    'display_login': 'etawia',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/etawia',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80437879?'},
#   'repo': {'id': 598997440,
#    'name': 'etawia/alx-system_engineering-devops',
#    'url': 'https://api.github.com/repos/etawia/alx-system_engineering-devops'},
#   'payload': {'repository_id': 598997440,
#    'push_id': 12628761396,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ca8d68a3806ca6907e47135913c33b994f45fd12',
#    'before': '002169101ae1d1b9b70774b4cb3a652006b8cf63',
#    'commits': [{'sha': 'ca8d68a3806ca6907e47135913c33b994f45fd12',
#      'author': {'email': 'tawiah.tetteh10@gmail.com', 'name': 'etawia'},
#      'message': 'crate local variables',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/etawia/alx-system_engineering-devops/commits/ca8d68a3806ca6907e47135913c33b994f45fd12'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195353',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 587608898,
#    'name': 'bd-ans/bd-ans',
#    'url': 'https://api.github.com/repos/bd-ans/bd-ans'},
#   'payload': {'repository_id': 587608898,
#    'push_id': 12628761316,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '720759b4bba34f79254a8fd2df699d3ed7e756eb',
#    'before': '776fea23a90c7d8923827aec59e4c4be11f5381f',
#    'commits': [{'sha': '720759b4bba34f79254a8fd2df699d3ed7e756eb',
#      'author': {'email': 'github-actions[bot]@users.noreply.github.com}',
#       'name': 'github-actions[bot]}'},
#      'message': '.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bd-ans/bd-ans/commits/720759b4bba34f79254a8fd2df699d3ed7e756eb'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195409',
#   'type': 'PushEvent',
#   'actor': {'id': 90841224,
#    'login': 'ivannf',
#    'display_login': 'ivannf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ivannf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90841224?'},
#   'repo': {'id': 602029481,
#    'name': 'ivannf/proyecto-angular',
#    'url': 'https://api.github.com/repos/ivannf/proyecto-angular'},
#   'payload': {'repository_id': 602029481,
#    'push_id': 12628761342,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0bcf8f2f1c4bd0c20626d943575a71ba52cee35a',
#    'before': '567ef2ad294ae1c95453c94eef629d89dc9b2e65',
#    'commits': [{'sha': '0bcf8f2f1c4bd0c20626d943575a71ba52cee35a',
#      'author': {'email': '=', 'name': '='},
#      'message': 'angular',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ivannf/proyecto-angular/commits/0bcf8f2f1c4bd0c20626d943575a71ba52cee35a'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195371',
#   'type': 'PushEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 325334313,
#    'name': 'MattZ6/musicians-hub-api',
#    'url': 'https://api.github.com/repos/MattZ6/musicians-hub-api'},
#   'payload': {'repository_id': 325334313,
#    'push_id': 12628761333,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/renovate/ioredis-5.x',
#    'head': '81a35b698c3d6fb1298452035de0b0a1ba30df7f',
#    'before': '01002a09a85bbc0650c19f5a343251d03632ba13',
#    'commits': [{'sha': '7f17982edb584fe53f586c7295b8f50449090384',
#      'author': {'email': '29139614+renovate[bot]@users.noreply.github.com',
#       'name': 'renovate[bot]'},
#      'message': 'chore(deps): update dependency prettier to v2.8.4',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/MattZ6/musicians-hub-api/commits/7f17982edb584fe53f586c7295b8f50449090384'},
#     {'sha': '8df3c45376c0af84327b8cb43d7fefe96f4e716d',
#      'author': {'email': 'matt_z6@hotmail.com',
#       'name': 'Matheus Felipe Zanin'},
#      'message': 'chore(deps): update dependency prettier to v2.8.4 (#469)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/MattZ6/musicians-hub-api/commits/8df3c45376c0af84327b8cb43d7fefe96f4e716d'},
#     {'sha': '81a35b698c3d6fb1298452035de0b0a1ba30df7f',
#      'author': {'email': '29139614+renovate[bot]@users.noreply.github.com',
#       'name': 'renovate[bot]'},
#      'message': 'fix(deps): update dependency ioredis to v5.3.1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MattZ6/musicians-hub-api/commits/81a35b698c3d6fb1298452035de0b0a1ba30df7f'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195317',
#   'type': 'PushEvent',
#   'actor': {'id': 79287829,
#    'login': 'montezdesousa',
#    'display_login': 'montezdesousa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/montezdesousa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79287829?'},
#   'repo': {'id': 602021856,
#    'name': 'montezdesousa/OpenBBTerminal',
#    'url': 'https://api.github.com/repos/montezdesousa/OpenBBTerminal'},
#   'payload': {'repository_id': 602021856,
#    'push_id': 12628761325,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/addin',
#    'head': '5f87caa5e377999bf4e35113a78f42a766095632',
#    'before': '3ddd86f73e06c97431caf580e654b9fc2ac29b27',
#    'commits': [{'sha': '5f87caa5e377999bf4e35113a78f42a766095632',
#      'author': {'email': '79287829+montezdesousa@users.noreply.github.com',
#       'name': 'montezdesousa'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/montezdesousa/OpenBBTerminal/commits/5f87caa5e377999bf4e35113a78f42a766095632'}]},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'},
#  {'id': '27105195433',
#   'type': 'CreateEvent',
#   'actor': {'id': 16620050,
#    'login': 'ridhoassuryadi',
#    'display_login': 'ridhoassuryadi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ridhoassuryadi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16620050?'},
#   'repo': {'id': 602043127,
#    'name': 'ridhoassuryadi/quartz',
#    'url': 'https://api.github.com/repos/ridhoassuryadi/quartz'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'hugo',
#    'description': '🌱 host your own second brain and digital garden for free',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-15T11:34:25Z'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                           type  \
# 0   27105195558                    IssuesEvent
# 1   27105195581              IssueCommentEvent
# 2   27105195609                    DeleteEvent
# 3   27105195458                      PushEvent
# 4   27105195547                      PushEvent
# 5   27105195474                      PushEvent
# 6   27105195506                      PushEvent
# 7   27105195504               PullRequestEvent
# 8   27105195500              IssueCommentEvent
# 9   27105195505                      PushEvent
# 10  27105195516                      PushEvent
# 11  27105195507         PullRequestReviewEvent
# 12  27105195543                      PushEvent
# 13  27105195489                    CreateEvent
# 14  27105195510               PullRequestEvent
# 15  27105195537                     WatchEvent
# 16  27105195464                      PushEvent
# 17  27105195460                    CreateEvent
# 18  27105195443                      PushEvent
# 19  27105195421  PullRequestReviewCommentEvent
# 20  27105195412                      PushEvent
# 21  27105195418                    PublicEvent
# 22  27105195410                      PushEvent
# 23  27105195406                      PushEvent
# 24  27105195449                      PushEvent
# 25  27105195353                      PushEvent
# 26  27105195409                      PushEvent
# 27  27105195371                      PushEvent
# 28  27105195317                      PushEvent
# 29  27105195433                    CreateEvent
#
#                                                 actor  \
# 0   {'id': 58094558, 'login': 'pddemo', 'display_l...
# 1   {'id': 19198355, 'login': 'artiely', 'display_...
# 2   {'id': 77505379, 'login': 'robert-craig-housto...
# 3   {'id': 41898282, 'login': 'github-actions[bot]...
# 4   {'id': 69813706, 'login': 'SalmanNaghori', 'di...
# 5   {'id': 8517910, 'login': 'LombiqBot', 'display...
# 6   {'id': 56868292, 'login': 'Zhytou', 'display_l...
# 7   {'id': 122006844, 'login': 'rioyulinanda', 'di...
# 8   {'id': 49699333, 'login': 'dependabot[bot]', '...
# 9   {'id': 95034083, 'login': 'kAmAZ07', 'display_...
# 10  {'id': 52163207, 'login': 'yanwhite1017', 'dis...
# 11  {'id': 614215, 'login': 'ecomodeller', 'displa...
# 12  {'id': 1919138, 'login': 'vnkolt', 'display_lo...
# 13  {'id': 121540704, 'login': 'Tanya-Gorecha', 'd...
# 14  {'id': 39814207, 'login': 'pull[bot]', 'displa...
# 15  {'id': 6018169, 'login': 'Bingzo', 'display_lo...
# 16  {'id': 41898282, 'login': 'github-actions[bot]...
# 17  {'id': 5978, 'login': 'brotherlogic', 'display...
# 18  {'id': 119851531, 'login': 'animaomnium', 'dis...
# 19  {'id': 12459061, 'login': 'oxisto', 'display_l...
# 20  {'id': 1318985, 'login': 'marianzburlea', 'dis...
# 21  {'id': 114900529, 'login': 'iliaquatali', 'dis...
# 22  {'id': 41898282, 'login': 'github-actions[bot]...
# 23  {'id': 79570884, 'login': 'RickHalmoguera', 'd...
# 24  {'id': 80437879, 'login': 'etawia', 'display_l...
# 25  {'id': 41898282, 'login': 'github-actions[bot]...
# 26  {'id': 90841224, 'login': 'ivannf', 'display_l...
# 27  {'id': 29139614, 'login': 'renovate[bot]', 'di...
# 28  {'id': 79287829, 'login': 'montezdesousa', 'di...
# 29  {'id': 16620050, 'login': 'ridhoassuryadi', 'd...
#
#                                                  repo  \
# 0   {'id': 277422872, 'name': 'pddemo/demo', 'url'...
# 1   {'id': 287952716, 'name': 'chexiongsheng/puert...
# 2   {'id': 553213531, 'name': 'Esri/date', 'url': ...
# 3   {'id': 367179710, 'name': 'kisaragi-hiu/aqi-mi...
# 4   {'id': 600827780, 'name': 'SalmanNaghori/shop_...
# 5   {'id': 86929735, 'name': 'Lombiq/Orchard', 'ur...
# 6   {'id': 486866465, 'name': 'Zhytou/Zhytou', 'ur...
# 7   {'id': 601073114, 'name': 'revou-fsse-1/w5-com...
# 8   {'id': 601934771, 'name': 'stream-protocol/str...
# 9   {'id': 527466952, 'name': 'kAmAZ07/Portfolio',...
# 10  {'id': 598791084, 'name': 'yanwhite1017/bybit_...
# 11  {'id': 168518417, 'name': 'DHI/mikeio', 'url':...
# 12  {'id': 599933527, 'name': 'vnkolt/sandbox.go',...
# 13  {'id': 602044316, 'name': 'Tanya-Gorecha/pneum...
# 14  {'id': 393763668, 'name': 'nin-echo/RSSHub', '...
# 15  {'id': 5552858, 'name': 'cyfdecyf/cow', 'url':...
# 16  {'id': 341017857, 'name': 'Codeize/Codeize', '...
# 17  {'id': 100546584, 'name': 'brotherlogic/remind...
# 18  {'id': 601085934, 'name': 'animaomnium/animaom...
# 19  {'id': 225386107, 'name': 'Fraunhofer-AISEC/cp...
# 20  {'id': 602040023, 'name': 'wowdop/blog-next-12...
# 21  {'id': 590427692, 'name': 'iliaquatali/Laravel...
# 22  {'id': 63333828, 'name': 'JasperFx/oakton', 'u...
# 23  {'id': 601752040, 'name': 'RickHalmoguera/Plan...
# 24  {'id': 598997440, 'name': 'etawia/alx-system_e...
# 25  {'id': 587608898, 'name': 'bd-ans/bd-ans', 'ur...
# 26  {'id': 602029481, 'name': 'ivannf/proyecto-ang...
# 27  {'id': 325334313, 'name': 'MattZ6/musicians-hu...
# 28  {'id': 602021856, 'name': 'montezdesousa/OpenB...
# 29  {'id': 602043127, 'name': 'ridhoassuryadi/quar...
#
#                                               payload  public  \
# 0   {'action': 'opened', 'issue': {'url': 'https:/...    True
# 1   {'action': 'created', 'issue': {'url': 'https:...    True
# 2   {'ref': 'rob10470/expr1058_update_date_to_lowe...    True
# 3   {'repository_id': 367179710, 'push_id': 126287...    True
# 4   {'repository_id': 600827780, 'push_id': 126287...    True
# 5   {'repository_id': 86929735, 'push_id': 1262876...    True
# 6   {'repository_id': 486866465, 'push_id': 126287...    True
# 7   {'action': 'opened', 'number': 5, 'pull_reques...    True
# 8   {'action': 'created', 'issue': {'url': 'https:...    True
# 9   {'repository_id': 527466952, 'push_id': 126287...    True
# 10  {'repository_id': 598791084, 'push_id': 126287...    True
# 11  {'action': 'created', 'review': {'id': 1299320...    True
# 12  {'repository_id': 599933527, 'push_id': 126287...    True
# 13  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 14  {'action': 'opened', 'number': 936, 'pull_requ...    True
# 15                              {'action': 'started'}    True
# 16  {'repository_id': 341017857, 'push_id': 126287...    True
# 17  {'ref': 'update-1676460852', 'ref_type': 'bran...    True
# 18  {'repository_id': 601085934, 'push_id': 126287...    True
# 19  {'action': 'created', 'comment': {'url': 'http...    True
# 20  {'repository_id': 602040023, 'push_id': 126287...    True
# 21                                                 {}    True
# 22  {'repository_id': 63333828, 'push_id': 1262876...    True
# 23  {'repository_id': 601752040, 'push_id': 126287...    True
# 24  {'repository_id': 598997440, 'push_id': 126287...    True
# 25  {'repository_id': 587608898, 'push_id': 126287...    True
# 26  {'repository_id': 602029481, 'push_id': 126287...    True
# 27  {'repository_id': 325334313, 'push_id': 126287...    True
# 28  {'repository_id': 602021856, 'push_id': 126287...    True
# 29  {'ref': 'master', 'ref_type': 'branch', 'maste...    True
#
#               created_at                                                org
# 0   2023-02-15T11:34:25Z                                                NaN
# 1   2023-02-15T11:34:25Z                                                NaN
# 2   2023-02-15T11:34:25Z  {'id': 628795, 'login': 'Esri', 'gravatar_id':...
# 3   2023-02-15T11:34:25Z                                                NaN
# 4   2023-02-15T11:34:25Z                                                NaN
# 5   2023-02-15T11:34:25Z  {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# 6   2023-02-15T11:34:25Z                                                NaN
# 7   2023-02-15T11:34:25Z  {'id': 119390055, 'login': 'revou-fsse-1', 'gr...
# 8   2023-02-15T11:34:25Z                                                NaN
# 9   2023-02-15T11:34:25Z                                                NaN
# 10  2023-02-15T11:34:25Z                                                NaN
# 11  2023-02-15T11:34:25Z  {'id': 32934768, 'login': 'DHI', 'gravatar_id'...
# 12  2023-02-15T11:34:25Z                                                NaN
# 13  2023-02-15T11:34:25Z                                                NaN
# 14  2023-02-15T11:34:25Z                                                NaN
# 15  2023-02-15T11:34:25Z                                                NaN
# 16  2023-02-15T11:34:25Z                                                NaN
# 17  2023-02-15T11:34:25Z                                                NaN
# 18  2023-02-15T11:34:25Z                                                NaN
# 19  2023-02-15T11:34:24Z  {'id': 11649721, 'login': 'Fraunhofer-AISEC', ...
# 20  2023-02-15T11:34:25Z  {'id': 86354869, 'login': 'wowdop', 'gravatar_...
# 21  2023-02-15T11:34:25Z                                                NaN
# 22  2023-02-15T11:34:25Z  {'id': 10048186, 'login': 'JasperFx', 'gravata...
# 23  2023-02-15T11:34:25Z                                                NaN
# 24  2023-02-15T11:34:25Z                                                NaN
# 25  2023-02-15T11:34:25Z                                                NaN
# 26  2023-02-15T11:34:25Z                                                NaN
# 27  2023-02-15T11:34:25Z                                                NaN
# 28  2023-02-15T11:34:25Z                                                NaN
# 29  2023-02-15T11:34:25Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id                           type  public            created_at  \
# 0   27105195558                    IssuesEvent    True  2023-02-15T11:34:25Z
# 1   27105195581              IssueCommentEvent    True  2023-02-15T11:34:25Z
# 2   27105195609                    DeleteEvent    True  2023-02-15T11:34:25Z
# 3   27105195458                      PushEvent    True  2023-02-15T11:34:25Z
# 4   27105195547                      PushEvent    True  2023-02-15T11:34:25Z
# 5   27105195474                      PushEvent    True  2023-02-15T11:34:25Z
# 6   27105195506                      PushEvent    True  2023-02-15T11:34:25Z
# 7   27105195504               PullRequestEvent    True  2023-02-15T11:34:25Z
# 8   27105195500              IssueCommentEvent    True  2023-02-15T11:34:25Z
# 9   27105195505                      PushEvent    True  2023-02-15T11:34:25Z
# 10  27105195516                      PushEvent    True  2023-02-15T11:34:25Z
# 11  27105195507         PullRequestReviewEvent    True  2023-02-15T11:34:25Z
# 12  27105195543                      PushEvent    True  2023-02-15T11:34:25Z
# 13  27105195489                    CreateEvent    True  2023-02-15T11:34:25Z
# 14  27105195510               PullRequestEvent    True  2023-02-15T11:34:25Z
# 15  27105195537                     WatchEvent    True  2023-02-15T11:34:25Z
# 16  27105195464                      PushEvent    True  2023-02-15T11:34:25Z
# 17  27105195460                    CreateEvent    True  2023-02-15T11:34:25Z
# 18  27105195443                      PushEvent    True  2023-02-15T11:34:25Z
# 19  27105195421  PullRequestReviewCommentEvent    True  2023-02-15T11:34:24Z
# 20  27105195412                      PushEvent    True  2023-02-15T11:34:25Z
# 21  27105195418                    PublicEvent    True  2023-02-15T11:34:25Z
# 22  27105195410                      PushEvent    True  2023-02-15T11:34:25Z
# 23  27105195406                      PushEvent    True  2023-02-15T11:34:25Z
# 24  27105195449                      PushEvent    True  2023-02-15T11:34:25Z
# 25  27105195353                      PushEvent    True  2023-02-15T11:34:25Z
# 26  27105195409                      PushEvent    True  2023-02-15T11:34:25Z
# 27  27105195371                      PushEvent    True  2023-02-15T11:34:25Z
# 28  27105195317                      PushEvent    True  2023-02-15T11:34:25Z
# 29  27105195433                    CreateEvent    True  2023-02-15T11:34:25Z
#
#      actor.id           actor.login   actor.display_login actor.gravatar_id  \
# 0    58094558                pddemo                pddemo
# 1    19198355               artiely               artiely
# 2    77505379  robert-craig-houston  robert-craig-houston
# 3    41898282   github-actions[bot]        github-actions
# 4    69813706         SalmanNaghori         SalmanNaghori
# 5     8517910             LombiqBot             LombiqBot
# 6    56868292                Zhytou                Zhytou
# 7   122006844          rioyulinanda          rioyulinanda
# 8    49699333       dependabot[bot]            dependabot
# 9    95034083               kAmAZ07               kAmAZ07
# 10   52163207          yanwhite1017          yanwhite1017
# 11     614215           ecomodeller           ecomodeller
# 12    1919138                vnkolt                vnkolt
# 13  121540704         Tanya-Gorecha         Tanya-Gorecha
# 14   39814207             pull[bot]                  pull
# 15    6018169                Bingzo                Bingzo
# 16   41898282   github-actions[bot]        github-actions
# 17       5978          brotherlogic          brotherlogic
# 18  119851531           animaomnium           animaomnium
# 19   12459061                oxisto                oxisto
# 20    1318985         marianzburlea         marianzburlea
# 21  114900529           iliaquatali           iliaquatali
# 22   41898282   github-actions[bot]        github-actions
# 23   79570884        RickHalmoguera        RickHalmoguera
# 24   80437879                etawia                etawia
# 25   41898282   github-actions[bot]        github-actions
# 26   90841224                ivannf                ivannf
# 27   29139614         renovate[bot]              renovate
# 28   79287829         montezdesousa         montezdesousa
# 29   16620050        ridhoassuryadi        ridhoassuryadi
#
#                                             actor.url  \
# 0                 https://api.github.com/users/pddemo
# 1                https://api.github.com/users/artiely
# 2   https://api.github.com/users/robert-craig-houston
# 3    https://api.github.com/users/github-actions[bot]
# 4          https://api.github.com/users/SalmanNaghori
# 5              https://api.github.com/users/LombiqBot
# 6                 https://api.github.com/users/Zhytou
# 7           https://api.github.com/users/rioyulinanda
# 8        https://api.github.com/users/dependabot[bot]
# 9                https://api.github.com/users/kAmAZ07
# 10          https://api.github.com/users/yanwhite1017
# 11           https://api.github.com/users/ecomodeller
# 12                https://api.github.com/users/vnkolt
# 13         https://api.github.com/users/Tanya-Gorecha
# 14             https://api.github.com/users/pull[bot]
# 15                https://api.github.com/users/Bingzo
# 16   https://api.github.com/users/github-actions[bot]
# 17          https://api.github.com/users/brotherlogic
# 18           https://api.github.com/users/animaomnium
# 19                https://api.github.com/users/oxisto
# 20         https://api.github.com/users/marianzburlea
# 21           https://api.github.com/users/iliaquatali
# 22   https://api.github.com/users/github-actions[bot]
# 23        https://api.github.com/users/RickHalmoguera
# 24                https://api.github.com/users/etawia
# 25   https://api.github.com/users/github-actions[bot]
# 26                https://api.github.com/users/ivannf
# 27         https://api.github.com/users/renovate[bot]
# 28         https://api.github.com/users/montezdesousa
# 29        https://api.github.com/users/ridhoassuryadi
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/58094558?  ...
# 1   https://avatars.githubusercontent.com/u/19198355?  ...
# 2   https://avatars.githubusercontent.com/u/77505379?  ...
# 3   https://avatars.githubusercontent.com/u/41898282?  ...
# 4   https://avatars.githubusercontent.com/u/69813706?  ...
# 5    https://avatars.githubusercontent.com/u/8517910?  ...
# 6   https://avatars.githubusercontent.com/u/56868292?  ...
# 7   https://avatars.githubusercontent.com/u/122006...  ...
# 8   https://avatars.githubusercontent.com/u/49699333?  ...
# 9   https://avatars.githubusercontent.com/u/95034083?  ...
# 10  https://avatars.githubusercontent.com/u/52163207?  ...
# 11    https://avatars.githubusercontent.com/u/614215?  ...
# 12   https://avatars.githubusercontent.com/u/1919138?  ...
# 13  https://avatars.githubusercontent.com/u/121540...  ...
# 14  https://avatars.githubusercontent.com/u/39814207?  ...
# 15   https://avatars.githubusercontent.com/u/6018169?  ...
# 16  https://avatars.githubusercontent.com/u/41898282?  ...
# 17      https://avatars.githubusercontent.com/u/5978?  ...
# 18  https://avatars.githubusercontent.com/u/119851...  ...
# 19  https://avatars.githubusercontent.com/u/12459061?  ...
# 20   https://avatars.githubusercontent.com/u/1318985?  ...
# 21  https://avatars.githubusercontent.com/u/114900...  ...
# 22  https://avatars.githubusercontent.com/u/41898282?  ...
# 23  https://avatars.githubusercontent.com/u/79570884?  ...
# 24  https://avatars.githubusercontent.com/u/80437879?  ...
# 25  https://avatars.githubusercontent.com/u/41898282?  ...
# 26  https://avatars.githubusercontent.com/u/90841224?  ...
# 27  https://avatars.githubusercontent.com/u/29139614?  ...
# 28  https://avatars.githubusercontent.com/u/79287829?  ...
# 29  https://avatars.githubusercontent.com/u/16620050?  ...
#
#                      payload.comment._links.self.href  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  https://api.github.com/repos/Fraunhofer-AISEC/...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                      payload.comment._links.html.href  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  https://github.com/Fraunhofer-AISEC/cpg/pull/1...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#              payload.comment._links.pull_request.href  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  https://api.github.com/repos/Fraunhofer-AISEC/...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.comment.start_line payload.comment.original_start_line  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
# 5                         NaN                                 NaN
# 6                         NaN                                 NaN
# 7                         NaN                                 NaN
# 8                         NaN                                 NaN
# 9                         NaN                                 NaN
# 10                        NaN                                 NaN
# 11                        NaN                                 NaN
# 12                        NaN                                 NaN
# 13                        NaN                                 NaN
# 14                        NaN                                 NaN
# 15                        NaN                                 NaN
# 16                        NaN                                 NaN
# 17                        NaN                                 NaN
# 18                        NaN                                 NaN
# 19                        NaN                                 NaN
# 20                        NaN                                 NaN
# 21                        NaN                                 NaN
# 22                        NaN                                 NaN
# 23                        NaN                                 NaN
# 24                        NaN                                 NaN
# 25                        NaN                                 NaN
# 26                        NaN                                 NaN
# 27                        NaN                                 NaN
# 28                        NaN                                 NaN
# 29                        NaN                                 NaN
#
#    payload.comment.start_side payload.comment.line  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
# 5                         NaN                  NaN
# 6                         NaN                  NaN
# 7                         NaN                  NaN
# 8                         NaN                  NaN
# 9                         NaN                  NaN
# 10                        NaN                  NaN
# 11                        NaN                  NaN
# 12                        NaN                  NaN
# 13                        NaN                  NaN
# 14                        NaN                  NaN
# 15                        NaN                  NaN
# 16                        NaN                  NaN
# 17                        NaN                  NaN
# 18                        NaN                  NaN
# 19                        NaN                 56.0
# 20                        NaN                  NaN
# 21                        NaN                  NaN
# 22                        NaN                  NaN
# 23                        NaN                  NaN
# 24                        NaN                  NaN
# 25                        NaN                  NaN
# 26                        NaN                  NaN
# 27                        NaN                  NaN
# 28                        NaN                  NaN
# 29                        NaN                  NaN
#
#    payload.comment.original_line payload.comment.side  \
# 0                            NaN                  NaN
# 1                            NaN                  NaN
# 2                            NaN                  NaN
# 3                            NaN                  NaN
# 4                            NaN                  NaN
# 5                            NaN                  NaN
# 6                            NaN                  NaN
# 7                            NaN                  NaN
# 8                            NaN                  NaN
# 9                            NaN                  NaN
# 10                           NaN                  NaN
# 11                           NaN                  NaN
# 12                           NaN                  NaN
# 13                           NaN                  NaN
# 14                           NaN                  NaN
# 15                           NaN                  NaN
# 16                           NaN                  NaN
# 17                           NaN                  NaN
# 18                           NaN                  NaN
# 19                          56.0                RIGHT
# 20                           NaN                  NaN
# 21                           NaN                  NaN
# 22                           NaN                  NaN
# 23                           NaN                  NaN
# 24                           NaN                  NaN
# 25                           NaN                  NaN
# 26                           NaN                  NaN
# 27                           NaN                  NaN
# 28                           NaN                  NaN
# 29                           NaN                  NaN
#
#    payload.comment.in_reply_to_id
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                   1.103689e+09
# 20                            NaN
# 21                            NaN
# 22                            NaN
# 23                            NaN
# 24                            NaN
# 25                            NaN
# 26                            NaN
# 27                            NaN
# 28                            NaN
# 29                            NaN
#
# [30 rows x 491 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code

# %%
response.url

# %%
response.json()

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code

# %%
response.url

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code

# %%
response.json()

# %%
from datetime import datetime
datetime.fromtimestamp(1645005884)

# %%
pd.to_datetime(1637772367, unit="s")
